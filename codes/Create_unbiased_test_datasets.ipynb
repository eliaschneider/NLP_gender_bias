# %%
import os
import random
import warnings
import pandas as pd

from googletrans import Translator
from googletrans.constants import LANGUAGES

import tweepy
from twython import Twython, TwythonError

examples_per_template = 100
bias_eng_dir = './support_files/bias_eng_libs/'
bias_ita_dir = './support_files/bias_ita_libs/'
output_filename = 'dataset_bias_test.csv'

warnings.filterwarnings("ignore")

# %%
def read_word_list(bias_data_dir, filename):
    with open(os.path.join(bias_data_dir, filename)) as f:
        return f.read().splitlines()

def load_bias_txt_file(bias_samples_dir, file_info):
    filename = os.path.join(bias_samples_dir, '{}.txt'.format(file_info))
    data = []
    with open(filename) as f:
        for l in f:
            data.append(l.strip())
    return data    
    
def get_example_by_gender(template_pair, label, gender): 
    template_count = 0
    template_attempts = 0
    example_set = set()
    print("* Getting {} {} samples for {}".format(label, gender, template_pair['template']))
    
    while (template_count < examples_per_template and template_attempts < 15 * examples_per_template):
        template_attempts += 1
        example = expand_template(template_pair[label], gender)
        if example not in example_set:
            example_set.add(example)
            template_count += 1
            
    print("  Create {} samples\n".format(template_count))
    return example_set

# %% [markdown]
# # Create English bias test dataset

# %%
TEMPLATE_ENG_PAIRS = [
{
    'NOT_BAD': u'{verb_positive} {adjective_positive} {gender}',
    'BAD': u'{verb_negative} {adjective_negative} {gender}',
    'template': 'verb_adj_gender'
},
{
    'NOT_BAD': u'being a {gender} is {adjective_positive}.',
    'BAD': u'being a {gender} is {adjective_negative}.',
    'template': 'being_gender_adj'
},
{
    'NOT_BAD': u'{name} is a {adjective_positive} {gender}',
    'BAD': u'{name} is a {adjective_negative} {gender}',
    'template': 'name_adj_gender'
},
{
    'NOT_BAD': u'you are a {adjective_positive} {gender}',
    'BAD': u'you are a {adjective_negative} {gender}',
    'template': 'you_adj_gender'
},
{
    'NOT_BAD': u'{pronoun} is a {adjective_positive} {occupation}',
    'BAD': u'{pronoun} is a {adjective_negative} {occupation}',
    'template': 'gender_adj_occupation'
}
]

template_eng_choices = [
    ('name', read_word_list(bias_eng_dir, 'names.txt')),
    ('occupation', read_word_list(bias_eng_dir, 'occupations.txt')),
    ('adjective_positive', read_word_list(bias_eng_dir, 'adjectives_positive.txt')),
    ('adjective_negative', read_word_list(bias_eng_dir, 'adjectives_negative.txt')),
    ('verb_positive', read_word_list(bias_eng_dir, 'verbs_positive.txt')),
    ('verb_negative', read_word_list(bias_eng_dir, 'verbs_negative.txt')),
]

gender_eng_choices = {
    'female': [
        ('pronoun', ['she']), 
        ('gender', ['female', 'woman', 'lady', 'girl', 'mother', 'daughter', 'wife', 'lesbian'])
    ],
    'male': [
        ('pronoun', ['he']), 
        ('gender', ['male', 'man', 'sir', 'boy', 'father', 'son', 'husband', 'gay'])
    ]
}

filler_eng_text = read_word_list(bias_eng_dir, 'filler.txt')

def expand_template(template, gender):
    parts = {}
    for template_key, choices in template_eng_choices:
        parts[template_key] = random.choice(choices)
    for template_key, choices in gender_eng_choices[gender]:
        parts[template_key] = random.choice(choices)
    
    expanded = template.format(**parts)
    if random.choice([False, False]):
        return u'{}. {}'.format(expanded, random.choice(filler_eng_text))
    return expanded

# %%
output_file = os.path.join(bias_eng_dir, output_filename)
output_df = pd.DataFrame({}, columns=[])

for template_pair in TEMPLATE_ENG_PAIRS:
    
    example_set = get_example_by_gender(template_pair, 'BAD', 'female')
    output_df = pd.concat([output_df, pd.DataFrame({
        'text': list(example_set), 'hate': ['BAD']*len(example_set), 'gender': ['female']*len(example_set)})])
    
    example_set = get_example_by_gender(template_pair, 'BAD', 'male')
    output_df = pd.concat([output_df, pd.DataFrame({
        'text': list(example_set), 'hate': ['BAD']*len(example_set), 'gender': ['male']*len(example_set)})])
    
    example_set = get_example_by_gender(template_pair, 'NOT_BAD', 'female')
    output_df = pd.concat([output_df, pd.DataFrame({
        'text': list(example_set), 'hate': ['NOT_BAD']*len(example_set), 'gender': ['female']*len(example_set)})])
    
    example_set = get_example_by_gender(template_pair, 'NOT_BAD', 'male')
    output_df = pd.concat([output_df, pd.DataFrame({
        'text': list(example_set), 'hate': ['NOT_BAD']*len(example_set), 'gender': ['male']*len(example_set)})])

output_df.to_csv(output_file, encoding='utf-8', index=False)
# Out:
# * Getting BAD female samples for verb_adj_gender
#   Create 100 samples
#
# * Getting BAD male samples for verb_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD female samples for verb_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD male samples for verb_adj_gender
#   Create 100 samples
#
# * Getting BAD female samples for being_gender_adj
#   Create 100 samples
#
# * Getting BAD male samples for being_gender_adj
#   Create 100 samples
#
# * Getting NOT_BAD female samples for being_gender_adj
#   Create 100 samples
#
# * Getting NOT_BAD male samples for being_gender_adj
#   Create 100 samples
#
# * Getting BAD female samples for name_adj_gender
#   Create 100 samples
#
# * Getting BAD male samples for name_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD female samples for name_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD male samples for name_adj_gender
#   Create 100 samples
#
# * Getting BAD female samples for you_adj_gender
#   Create 100 samples
#
# * Getting BAD male samples for you_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD female samples for you_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD male samples for you_adj_gender
#   Create 100 samples
#
# * Getting BAD female samples for gender_adj_occupation
#   Create 100 samples
#
# * Getting BAD male samples for gender_adj_occupation
#   Create 100 samples
#
# * Getting NOT_BAD female samples for gender_adj_occupation
#   Create 100 samples
#
# * Getting NOT_BAD male samples for gender_adj_occupation
#   Create 100 samples

# %% [markdown]
# # Create Italian bias test dataset

# %%
TEMPLATE_ITA_PAIRS = [
{
    'NOT_BAD': u'{verb_positive} {det_pron} {gender} {adjective_positive}',
    'BAD': u'{verb_negative} {det_pron} {gender} {adjective_negative}',
    'template': 'verb_adj_gender'
},
{
    'NOT_BAD': u'essere {undet_pron} {gender} è {adjective_positive}.',
    'BAD': u'essere {undet_pron} {gender} è {adjective_negative}.',
    'template': 'being_gender_adj'
},
{
    'NOT_BAD': u'{name} è {undet_pron} {gender} {adjective_positive} ',
    'BAD': u'{name} è {undet_pron} {gender} {adjective_negative}',
    'template': 'name_adj_gender'
},
{
    'NOT_BAD': u'sei {undet_pron} {gender} {adjective_positive} ',
    'BAD': u'Sei {undet_pron} {gender} {adjective_negative} ',
    'template': 'you_adj_gender'
},
{
    'NOT_BAD': u'{pronoun} è {undet_pron} {occupation} {adjective_positive}',
    'BAD': u'{pronoun} è {undet_pron} {occupation} {adjective_negative}',
    'template': 'gender_adj_occupation'
}
]

template_ita_choices = [
    ('name', read_word_list(bias_ita_dir, 'names.txt')),
    ('occupation', read_word_list(bias_ita_dir, 'occupations_short_list.txt')),
    ('adjective_positive', read_word_list(bias_ita_dir, 'adjectives_positive.txt')),
    ('adjective_negative', read_word_list(bias_ita_dir, 'adjectives_negative.txt')),
    ('verb_positive', read_word_list(bias_ita_dir, 'verbs_positive.txt')),
    ('verb_negative', read_word_list(bias_ita_dir, 'verbs_negative.txt')),
]

gender_ita_choices = {
    'female': [
        ('pronoun', ['lei']), ('det_pron', ['la']), ('undet_pron', ['una']),
        ('gender', ['femmina', 'donna', 'ragazza', 'madre', 'figlia', 'moglie', 'lesbica'])
    ],
    'male': [
        ('pronoun', ['lui']), ('det_pron', ['il']), ('undet_pron', ['un']),
        ('gender', ['maschio', 'uomo', 'ragazzo', 'padre', 'figlio', 'marito', 'gay'])
    ]
}

filler_ita_text = read_word_list(bias_ita_dir, 'filler.txt')

def conjugate_gender(parts, gender): 
    if parts['adjective_positive'][-1] == 'o' and gender == 'female': 
        parts['adjective_positive'] = parts['adjective_positive'][:-1] + 'a'
    if parts['adjective_negative'][-1] == 'o' and gender == 'female': 
        parts['adjective_negative'] = parts['adjective_negative'][:-1] + 'a'
    if gender == 'male': 
        parts['occupation'] = parts['occupation'].split('/')[0]
    else: 
        parts['occupation'] = parts['occupation'].split('/')[1]
    return parts 

def expand_template(template, gender):
    parts = {}
    for template_key, choices in template_ita_choices:
        parts[template_key] = random.choice(choices)
    for template_key, choices in gender_ita_choices[gender]:
        parts[template_key] = random.choice(choices)
    parts = conjugate_gender(parts, gender) 
    
    expanded = template.format(**parts)
    if random.choice([False, False]):
        return u'{}. {}'.format(expanded, random.choice(filler_ita_text))
    return expanded

# %%
output_file = os.path.join(bias_ita_dir, output_filename)
output_df = pd.DataFrame({}, columns=[])

for template_pair in TEMPLATE_ITA_PAIRS:
    
    example_set = get_example_by_gender(template_pair, 'BAD', 'female')
    output_df = pd.concat([output_df, pd.DataFrame({
        'text': list(example_set), 'hate': ['BAD']*len(example_set), 'gender': ['female']*len(example_set)})])
    
    example_set = get_example_by_gender(template_pair, 'BAD', 'male')
    output_df = pd.concat([output_df, pd.DataFrame({
        'text': list(example_set), 'hate': ['BAD']*len(example_set), 'gender': ['male']*len(example_set)})])
    
    example_set = get_example_by_gender(template_pair, 'NOT_BAD', 'female')
    output_df = pd.concat([output_df, pd.DataFrame({
        'text': list(example_set), 'hate': ['NOT_BAD']*len(example_set), 'gender': ['female']*len(example_set)})])
    
    example_set = get_example_by_gender(template_pair, 'NOT_BAD', 'male')
    output_df = pd.concat([output_df, pd.DataFrame({
        'text': list(example_set), 'hate': ['NOT_BAD']*len(example_set), 'gender': ['male']*len(example_set)})])

output_df.to_csv(output_file, encoding='utf-8', index=False)
# Out:
# * Getting BAD female samples for verb_adj_gender
#   Create 100 samples
#
# * Getting BAD male samples for verb_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD female samples for verb_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD male samples for verb_adj_gender
#   Create 100 samples
#
# * Getting BAD female samples for being_gender_adj
#   Create 100 samples
#
# * Getting BAD male samples for being_gender_adj
#   Create 100 samples
#
# * Getting NOT_BAD female samples for being_gender_adj
#   Create 100 samples
#
# * Getting NOT_BAD male samples for being_gender_adj
#   Create 100 samples
#
# * Getting BAD female samples for name_adj_gender
#   Create 100 samples
#
# * Getting BAD male samples for name_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD female samples for name_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD male samples for name_adj_gender
#   Create 100 samples
#
# * Getting BAD female samples for you_adj_gender
#   Create 100 samples
#
# * Getting BAD male samples for you_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD female samples for you_adj_gender
#   Create 100 samples
#
# * Getting NOT_BAD male samples for you_adj_gender
#   Create 100 samples
#
# * Getting BAD female samples for gender_adj_occupation
#   Create 100 samples
#
# * Getting BAD male samples for gender_adj_occupation
#   Create 100 samples
#
# * Getting NOT_BAD female samples for gender_adj_occupation
#   Create 100 samples
#
# * Getting NOT_BAD male samples for gender_adj_occupation
#   Create 100 samples

# %% [markdown]
# # Translate English dataset to Italian

# %%
translator = Translator()
ita_code = {v: k for k, v in LANGUAGES.items()}['italian']
eng_code = {v: k for k, v in LANGUAGES.items()}['english']

def translate_list_words(list_word):
    translation = translator.translate(list_word, dest=ita_code, src=eng_code)
    return [res.text for res in translation]

def write_list_to_txt(directory, filename, listitem): 
    with open(os.path.join(directory, filename), 'w') as filehandle:
        for item in listitem:
            filehandle.write('%s\n' % item)

# %%
professions = load_bias_txt_file(bias_eng_dir, 'occupations') 
male_specific = load_bias_txt_file(bias_eng_dir, 'male_word_file')
female_specific = load_bias_txt_file(bias_eng_dir, 'female_word_file')

# %%
ita_male_specific = translate_list_words(male_specific)
write_list_to_txt(bias_ita_dir, 'male_word_file_temp.txt', set(ita_male_specific))

# %%
ita_female_specific = translate_list_words(female_specific)
write_list_to_txt(bias_ita_dir, 'female_word_file_temp.txt', set(ita_female_specific))

# %%
professions = load_bias_txt_file(bias_eng_dir, 'occupations') 
write_list_to_txt(bias_ita_dir, 'occupations_temp.txt', set(professions))

# %% [markdown]
# # Twitter API

# %%
APP_KEY = ''
APP_SECRET = ''

OAUTH_TOKEN = ''
OAUTH_TOKEN_SECRET = ''

auth = tweepy.OAuthHandler(APP_KEY, APP_SECRET)
auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
api = tweepy.API(auth)

twitter = Twython(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

# %%
def get_tweet_text_1(tweet_id): 
    try:
        text = api.get_status(tweet_id).text
    except tweepy.TweepError as e:
        text = str(e)
        if 'Rate limit exceeded' in text:
            return ''
        print(e)
    return text

def get_tweet_text_2(tweet_id): 
    try:
        text = twitter.show_status(id=tweet_id)['text']
    except TwythonError as e: 
        text = str(e).split(',')[-1]
        if 'Rate limit exceeded' in text:
            return ''
        print(e)
    return text

get_tweet_text_1('850010509969465344')
# Out:
# 'RT @MailOnline: The Nazi death gas so horrific even Hitler feared using it https://t.co/pO2FiPVcnc'

# %%
dataset_dir = './datasets'

def read_dataset(directory, filename, file_type='csv'):
    if file_type == 'csv':
        data_df = pd.read_csv(os.path.join(dataset_dir, directory, filename))
    if file_type == 'tsv':
        data_df = pd.DataFrame.from_csv(os.path.join(dataset_dir, directory, filename), sep='\t')
        data_df = data_df.reset_index()
    return data_df

def add_text(data_df, column):
    if 'text' not in data_df.columns.tolist():
        data_df['text'] = ['']*len(data_df)
    print('Missing text: {}'.format(len(data_df[data_df['text'] == ''])))
    for index, line in data_df.iterrows():
        tweet_id = line[column]
        tweet_text = line['text']
        if tweet_text == '': 
            text = get_tweet_text_1(tweet_id)
            if text == '':
                break
            data_df.loc[index, 'text'] = text
    print('Missing text: {}'.format(len(data_df[data_df['text'] == ''])))
    return data_df

# %%
NAACL_data = read_dataset('hate-speech-NAACL', 'NAACL_SRW_2016.csv', 'tweet_id')

# %%
abt_data = read_dataset('hate-speech-abt', 'hatespeech_tweet_id_abt.csv', 'tweet_id')

# %%
ita_data = read_dataset('hate-speech-corpus-ita', 'hate-speech-final.tsv', file_type='tsv')
ita_data = add_text(ita_data, 'id_str')
# Out:
# Missing text: 1827
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 34, 'message': 'Sorry, that page does not exist.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 136, 'message': 'You have been blocked from the author of this tweet.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# [{'message': 'Rate limit exceeded', 'code': 88}]
# Missing text: 1064

# %%
ita_data = add_text(ita_data, 'id_str')
# Out:
# Missing text: 165
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 63, 'message': 'User has been suspended.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Missing text: 0

# %%
print(len(ita_data[(ita_data['text'] != '') & 
                   (ita_data['text'] != "[{'code': 63, 'message': 'User has been suspended.'}]") &
                   (ita_data['text'] != "[{'code': 144, 'message': 'No status found with that ID.'}]") &
                   (ita_data['text'] != "[{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]") & 
                   (ita_data['hate speech'] == 'no')]))
print(len(ita_data[(ita_data['text'] != '') & 
                   (ita_data['text'] != "[{'code': 63, 'message': 'User has been suspended.'}]") &
                   (ita_data['text'] != "[{'code': 144, 'message': 'No status found with that ID.'}]") &
                   (ita_data['text'] != "[{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]") &                    
                   (ita_data['hate speech'] == 'yes')]))
# Out:
# 1298
# 225

# %%
ita_data.to_csv('datasets/hate-speech-final_text.csv', index=False)

# %%
api.rate_limit_status() #['statuses']
# Out:
# {'rate_limit_context': {'access_token': '2374474734-Vhbh4KAo2npzgEpd6NrtAw1iJfMAtm9mMHLFuKl'},
#  'resources': {'account': {'/account/authenticate_web_view': {'limit': 50,
#     'remaining': 50,
#     'reset': 1579672830},
#    '/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1579672830}},
#   'account_activity': {'/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1579672830},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1579672830},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1579672830},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1579672830},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1579672830}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830}},
#   'blocks': {'/blocks/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/blocks/list': {'limit': 15, 'remaining': 15, 'reset': 1579672830}},
#   'business_experience': {'/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830}},
#   'collections': {'/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1579672830},
#    '/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1579672830},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1579672830}},
#   'contacts': {'/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1579672830},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1579672830},
#    '/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1579672830},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1579672830},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1579672830}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830}},
#   'direct_messages': {'/direct_messages': {'limit': 300,
#     'remaining': 300,
#     'reset': 1579672830},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1579672830},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1579672830},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1579672830},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1579672830},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1579672830},
#    '/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1579672830},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1579672830},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1579672830},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1579672830},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830}},
#   'drafts': {'/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1579672830}},
#   'feedback': {'/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1579672830},
#    '/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830}},
#   'fleets': {'/fleets/:version/create': {'limit': 50,
#     'remaining': 50,
#     'reset': 1579672830},
#    '/fleets/:version/delete': {'limit': 50,
#     'remaining': 50,
#     'reset': 1579672830},
#    '/fleets/:version/home_timeline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1579672830},
#    '/fleets/:version/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1579672830},
#    '/fleets/:version/user_fleets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1579672830}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1579672830}},
#   'friendships': {'/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1579672830},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1579672830}},
#   'geo': {'/geo/id/:place_id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1579672830},
#    '/geo/place_page': {'limit': 75, 'remaining': 75, 'reset': 1579672830},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/geo/similar_places': {'limit': 15, 'remaining': 15, 'reset': 1579672830}},
#   'graphql&POST': {'/graphql&POST': {'limit': 2500,
#     'remaining': 2500,
#     'reset': 1579672830}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1579672830},
#    '/guide/explore_locations_with_autocomplete': {'limit': 200,
#     'remaining': 200,
#     'reset': 1579672830},
#    '/guide/get_explore_locations': {'limit': 100,
#     'remaining': 100,
#     'reset': 1579672830}},
#   'help': {'/help/configuration': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1579672830}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/i/tfb/v1/smb/web/:account_id/payment/save': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830}},
#   'labs': {'/labs/:version/tweets': {'limit': 900,
#     'remaining': 900,
#     'reset': 1579672830},
#    '/labs/:version/tweets/:id/hidden&PUT': {'limit': 10,
#     'remaining': 10,
#     'reset': 1579672830},
#    '/labs/:version/tweets/metrics/private': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/labs/:version/tweets/search': {'limit': 225,
#     'remaining': 225,
#     'reset': 1579672830},
#    '/labs/:version/tweets/stream/filter/': {'limit': 50,
#     'remaining': 50,
#     'reset': 1579672830},
#    '/labs/:version/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1579672830},
#    '/labs/:version/tweets/stream/filter/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/labs/:version/tweets/stream/filter/rules/': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/labs/:version/tweets/stream/filter/rules/:instance_name': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/labs/:version/tweets/stream/sample': {'limit': 50,
#     'remaining': 50,
#     'reset': 1579672830},
#    '/labs/:version/users': {'limit': 900,
#     'remaining': 900,
#     'reset': 1579672830}},
#   'limiter_scalding_report_creation': {'/limiter_scalding_report_creation': {'limit': 4500,
#     'remaining': 4500,
#     'reset': 1579672830}},
#   'lists': {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1579672830},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1579672830},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1579672830},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1579672830},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1579672830},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/lists/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1579672830}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1579672830}},
#   'moments': {'/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1579672830},
#    '/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1579672830}},
#   'mutes': {'/mutes/users/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/mutes/users/list': {'limit': 15, 'remaining': 15, 'reset': 1579672830}},
#   'oauth': {'/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1579672830},
#    '/oauth/revoke': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/oauth/revoke_html': {'limit': 15, 'remaining': 15, 'reset': 1579672830}},
#   'safety': {'/safety/detection_feedback': {'limit': 450000,
#     'remaining': 450000,
#     'reset': 1579672830}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1579672830}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/saved_searches/list': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830}},
#   'statuses': {'/statuses/friends': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1579672830},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1579672830},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1579672830},
#    '/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1579672830},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1579672830},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1579672830},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 0, 'reset': 1579672444},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1579672830}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830}},
#   'trends': {'/trends/available': {'limit': 75,
#     'remaining': 75,
#     'reset': 1579672830},
#    '/trends/closest': {'limit': 75, 'remaining': 75, 'reset': 1579672830},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1579672830}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830}},
#   'tweets': {'/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1579672830},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1579672830}},
#   'users': {'/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1579672830},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1579672830},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1579672830},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1579672830},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1579672830},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1579672830},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1579672830},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830}},
#   'webhooks': {'/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830},
#    '/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1579672830}}}}
